# %% [markdown]
# Note to self, convolution is matrix multiplication of a specified size of image with the kernel matrix.

# %% [raw]
# The normal neural network trains at the following rate

# %% [markdown]
# ![image.png](attachment:bd4e1f47-b2fd-4b4e-a5ce-7da53001d5ea.png)

# %% [markdown]
# The one with 16 kernels each would take the following amount of time

# %% [markdown]
# ![image.png](attachment:bcdb1b32-9839-49df-a198-da46c1e9b7d3.png)

# %% [markdown]
# The one with 32 kernels would take the following amount of time

# %% [markdown]
# ![image.png](attachment:b840310c-6f83-4885-b879-66018e6e8394.png)

# %% [markdown]
# The one with 64 layers would take the following amount of time

# %% [markdown]
# First attempt
# ![image.png](attachment:a50d7717-6c63-4c47-bdbd-3d464d2733aa.png)
# Second attempt
# ![image.png](attachment:5da017cf-4351-431e-ac6e-f44412c4f5e0.png)

# %% [markdown]
# Now when changing the alternate values kernels in each convolution layer would lead to the following timings
# 1st layer 32
# 2nd layer 16

# %% [markdown]
# ![image.png](attachment:988a9529-2da8-4ad7-9509-d764fe24d25b.png)

# %% [markdown]
# 1st layer 16
# 2nd layer 32

# %% [markdown]
# ![image.png](attachment:f2b5b317-5c0a-4af6-b4a0-c5cee03c97a5.png)
